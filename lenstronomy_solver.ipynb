# %%
try:
    # %load_ext autotime
except:
    # !pip install ipython-autotime
    # %load_ext autotime
# Out:
# time: 239 µs (started: 2022-11-15 21:56:45 +08:00)

# %%
# check python version
# lensinggw package requires python 3.8+

! python --version
# Out:
# Python 3.9.13
# time: 135 ms (started: 2022-11-15 21:56:46 +08:00)

# %%
# import libraries and packages

import random
import matplotlib.pyplot as plt
import numpy as np
import configparser
import pandas as pd
# Out:
# time: 811 ms (started: 2022-11-15 21:56:47 +08:00)

# %%
# !pip install lenstronomy
# Out:
# Requirement already satisfied: lenstronomy in /Users/genebelinario/opt/anaconda3/lib/python3.9/site-packages/lenstronomy-1.5.1-py3.9.egg (1.5.1)
# Requirement already satisfied: numpy>=1.13 in /Users/genebelinario/opt/anaconda3/lib/python3.9/site-packages (from lenstronomy) (1.21.5)
# Requirement already satisfied: scipy>=0.14.0 in /Users/genebelinario/opt/anaconda3/lib/python3.9/site-packages (from lenstronomy) (1.9.1)
# Requirement already satisfied: configparser in /Users/genebelinario/opt/anaconda3/lib/python3.9/site-packages/configparser-5.3.0-py3.9.egg (from lenstronomy) (5.3.0)
# time: 1.5 s (started: 2022-11-15 21:56:49 +08:00)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 py.test
#
# NameError: name 'py' is not defined
# time: 40.1 ms (started: 2022-11-15 21:42:23 +08:00)
